# %%
import sys
sys.path.append('../..')
from utils.data import RK4DataGenerator, stack_real_values, mono_beta, sin_beta
import utils.plotting as plotting
import numpy as np

# %%
test_t = np.linspace(0, 50, 100)

# %%
mono_beta_t = mono_beta(test_t)
plotting.plot_beta_example(mono_beta_t, test_t, "mono-beta-example")

# %%
sin_beta_t = sin_beta(test_t)
plotting.plot_beta_example(sin_beta_t, test_t, "sin-beta-example")
