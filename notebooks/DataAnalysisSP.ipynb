# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(
    # "../data/SG-ES.csv", 
    "../../../Downloads/SG-SP.csv", 
    parse_dates=["dataNotificacao", "dataEncerramento"], 
    encoding="utf-8", 
    sep=";"
)

df
# Out:
# /tmp/ipykernel_6210/3702339617.py:1: DtypeWarning: Columns (12,21,23,31,33,34,36,37,57,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#                                                   sintomas profissionalSaude  \
# 0                                   Tosse, Dor de Garganta               Não
# 1        Distúrbios Olfativos, Tosse, Dor de Garganta, ...               Não
# 2                             Dor de Cabeça, Febre, Outros               Não
# 3                                            Coriza, Tosse               Não
# 4                   Coriza, Tosse, Dor de Garganta, Outros               Não
# ...                                                    ...               ...
# 2226518                               Coriza, Tosse, Febre               Não
# 2226519      Dor de Cabeça, Tosse, Dor de Garganta, Outros               Não
# 2226520                Dor de Cabeça, Tosse, Febre, Outros               Não
# 2226521                Dor de Cabeça, Tosse, Febre, Coriza               Não
# 2226522                                    Tosse, Dispneia               Não
#
#           racaCor             outrosSintomas outrasCondicoes  \
# 0        Ignorado                        NaN             NaN
# 1        Ignorado                        NaN             NaN
# 2          Branca  tontura, vômito, diarréia             NaN
# 3          Branca                        NaN             NaN
# 4           Preta                  Calafrios             NaN
# ...           ...                        ...             ...
# 2226518   Amarela                        NaN             NaN
# 2226519    Branca                     FADIGA             NaN
# 2226520    Branca                    MIALGIA             NaN
# 2226521    Branca                        NaN             NaN
# 2226522  Ignorado                        NaN             NaN
#
#         profissionalSeguranca  cbo                   condicoes       sexo  \
# 0                         Não  NaN                         NaN  Masculino
# 1                         Não  NaN                         NaN   Feminino
# 2                         Não  NaN  Doenças cardíacas crônicas   Feminino
# 3                         Não  NaN                         NaN  Masculino
# 4                         Não  NaN                         NaN   Feminino
# ...                       ...  ...                         ...        ...
# 2226518                   Não  NaN                         NaN   Feminino
# 2226519                   Não  NaN                         NaN  Masculino
# 2226520                   Não  NaN                         NaN   Feminino
# 2226521                   Não  NaN                         NaN  Masculino
# 2226522                   Não  NaN                         NaN  Masculino
#
#             estado  ... codigoResultadoTeste3 codigoEstadoTeste4  \
# 0        São Paulo  ...                   NaN                NaN
# 1        São Paulo  ...                   NaN                NaN
# 2        São Paulo  ...                   NaN                NaN
# 3        São Paulo  ...                   NaN                NaN
# 4        São Paulo  ...                   NaN                NaN
# ...            ...  ...                   ...                ...
# 2226518  São Paulo  ...                   NaN                NaN
# 2226519  São Paulo  ...                   NaN                NaN
# 2226520  São Paulo  ...                   NaN                NaN
# 2226521  São Paulo  ...                   NaN                NaN
# 2226522  São Paulo  ...                   NaN                NaN
#
#         codigoTipoTeste4 codigoFabricanteTeste4 codigoResultadoTeste4  \
# 0                    NaN                    NaN                   NaN
# 1                    NaN                    NaN                   NaN
# 2                    NaN                    NaN                   NaN
# 3                    NaN                    NaN                   NaN
# 4                    NaN                    NaN                   NaN
# ...                  ...                    ...                   ...
# 2226518              NaN                    NaN                   NaN
# 2226519              NaN                    NaN                   NaN
# 2226520              NaN                    NaN                   NaN
# 2226521              NaN                    NaN                   NaN
# 2226522              NaN                    NaN                   NaN
#
#         dataColetaTeste1  dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  \
# 0             2022-07-02               NaN              NaN              NaN
# 1             2022-01-18               NaN              NaN              NaN
# 2             2022-10-07               NaN              NaN              NaN
# 3             2022-06-24               NaN              NaN              NaN
# 4             2022-07-20               NaN              NaN              NaN
# ...                  ...               ...              ...              ...
# 2226518       2022-05-26        2022-05-26              NaN              NaN
# 2226519       2022-08-24               NaN              NaN              NaN
# 2226520       2024-04-29               NaN              NaN              NaN
# 2226521       2022-01-19               NaN              NaN              NaN
# 2226522       2022-05-12               NaN              NaN              NaN
#
#          idade
# 0         50.0
# 1         28.0
# 2         40.0
# 3         42.0
# 4         32.0
# ...        ...
# 2226518    NaN
# 2226519    NaN
# 2226520    NaN
# 2226521   38.0
# 2226522    NaN
#
# [2226523 rows x 64 columns]

# %%
date_range = pd.date_range(
    # start=df['dataInicioSintomas'].min(), Notificação ou início dos sintomas?
    start=df['dataNotificacao'].min(),
    end=df['dataEncerramento'].max(),
    freq='D'
)

sir = pd.DataFrame(
    index=date_range, 
    columns=['I', 'R'], 
    dtype='int'
)

# %%
df[df["dataEncerramento"].isnull()].shape[0]
# Out:
# 1022715

# %%
# df = df.dropna(axis=0, subset=['dataEncerramento'])

# %%
pd.set_option('future.no_silent_downcasting', True)
sir = sir.fillna(0)

for i, row in df.iterrows():
    
    start = row['dataNotificacao']
    end = start + pd.Timedelta(days=7)
    # end = row['dataEncerramento']
    
    if pd.isna(end):  
        sir.loc[start:, 'I'] += 1
    else: 
        assert start <= end, f"Inconsistency at row {i}, start={start}, end={end}"
        sir.loc[start:end - pd.Timedelta(days=1), 'I'] += 1
        sir.loc[end:, 'R'] += 1

# %%
sir
# Out:
#                I          R
# 2020-01-01   1.0        0.0
# 2020-01-02   2.0        0.0
# 2020-01-03   3.0        0.0
# 2020-01-04   5.0        0.0
# 2020-01-05  10.0        0.0
# ...          ...        ...
# 2025-09-05   1.0  2226502.0
# 2025-09-06   1.0  2226502.0
# 2025-09-07   1.0  2226502.0
# 2025-09-08   0.0  2226503.0
# 2025-09-09   0.0  2226503.0
#
# [2079 rows x 2 columns]

# %%
sir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2079 entries, 2020-01-01 to 2025-09-09
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I       2079 non-null   float64
#  1   R       2079 non-null   float64
# dtypes: float64(2)
# memory usage: 113.3 KB

# %%
sns.lineplot(data=sir["I"])
plt.show()

# %%
sns.lineplot(data=sir["I"]["2024-01-01":"2025-01-01"])
plt.show()

# %%
smoothed_sir = sir.rolling(window=7).mean() 
sns.lineplot(data=smoothed_sir["I"]["2024-01-01":"2025-01-01"])
plt.show()

# %%
smoothed_sir = sir.rolling(window=7).mean() 
sns.lineplot(data=smoothed_sir["I"]["2022-01-01":"2023-01-01"])
plt.title("2022")
plt.show()

# %%
sns.lineplot(data=smoothed_sir["I"]["2023-01-01":"2024-01-01"])
plt.title("2023")
plt.show()

# %%
sns.scatterplot(data=smoothed_sir["I"]["2023-01-01":"2024-01-01"])
plt.title("2023")
plt.show()
