# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(
    # "../data/SG-ES.csv", 
    "../../../Downloads/SG-BA.csv", 
    parse_dates=["dataNotificacao", "dataEncerramento"], 
    encoding="utf-8", 
    sep=";"
)

df
# Out:
# /tmp/ipykernel_4411/3898036172.py:1: DtypeWarning: Columns (12,26,31,33,34,37,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#                                                  sintomas profissionalSaude  \
# 0                                                   Febre               Não
# 1                            Coriza, Dor de Cabeça, Tosse               Não
# 2                                         Dor de Garganta               Não
# 3                        Tosse, Dor de Garganta, Dispneia               Não
# 4       Coriza, Dor de Cabeça, Febre, Dor de Garganta,...               Não
# ...                                                   ...               ...
# 202095                                      Assintomático               Não
# 202096      Coriza, Dor de Cabeça, Tosse, Dispneia, Febre               Não
# 202097                              Dor de Cabeça, Coriza               Não
# 202098                                      Assintomático               Não
# 202099                                      Assintomático               Não
#
#          racaCor outrosSintomas outrasCondicoes profissionalSeguranca  cbo  \
# 0          Parda            NaN             NaN                   Não  NaN
# 1          Parda            NaN             NaN                   Não  NaN
# 2          Parda            NaN             NaN                   Não  NaN
# 3       Ignorado            NaN             NaN                   Não  NaN
# 4       Ignorado            NaN             NaN                   Não  NaN
# ...          ...            ...             ...                   ...  ...
# 202095    Branca            NaN             NaN                   Não  NaN
# 202096     Parda            NaN             NaN                   Não  NaN
# 202097    Branca            NaN             NaN                   Não  NaN
# 202098  Ignorado            NaN             NaN                   Não  NaN
# 202099    Branca            NaN             NaN                   Não  NaN
#
#                                             condicoes       sexo estado  ...  \
# 0                          Doenças cardíacas crônicas  Masculino  Bahia  ...
# 1                                                 NaN   Feminino  Bahia  ...
# 2                                                 NaN   Feminino  Bahia  ...
# 3                                                 NaN   Feminino  Bahia  ...
# 4                                                 NaN  Masculino  Bahia  ...
# ...                                               ...        ...    ...  ...
# 202095                                            NaN   Feminino  Bahia  ...
# 202096                                            NaN   Feminino  Bahia  ...
# 202097                                            NaN  Masculino  Bahia  ...
# 202098                                            NaN   Feminino  Bahia  ...
# 202099  Doenças respiratórias crônicas descompensadas  Masculino  Bahia  ...
#
#        codigoResultadoTeste3 codigoEstadoTeste4 codigoTipoTeste4  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 202095                   NaN                NaN              NaN
# 202096                   NaN                NaN              NaN
# 202097                   NaN                NaN              NaN
# 202098                   NaN                NaN              NaN
# 202099                   NaN                NaN              NaN
#
#        codigoFabricanteTeste4 codigoResultadoTeste4 dataColetaTeste1  \
# 0                         NaN                   NaN              NaN
# 1                         NaN                   NaN       2022-07-01
# 2                         NaN                   NaN       2022-07-01
# 3                         NaN                   NaN       2022-01-26
# 4                         NaN                   NaN              NaN
# ...                       ...                   ...              ...
# 202095                    NaN                   NaN       2022-06-13
# 202096                    NaN                   NaN       2022-02-01
# 202097                    NaN                   NaN       2021-04-19
# 202098                    NaN                   NaN       2022-01-20
# 202099                    NaN                   NaN       2022-02-15
#
#         dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0                    NaN              NaN              NaN    NaN
# 1                    NaN              NaN              NaN    NaN
# 2                    NaN              NaN              NaN   52.0
# 3                    NaN              NaN              NaN   53.0
# 4                    NaN              NaN              NaN   46.0
# ...                  ...              ...              ...    ...
# 202095               NaN              NaN              NaN    NaN
# 202096               NaN              NaN              NaN   44.0
# 202097               NaN              NaN              NaN   36.0
# 202098               NaN              NaN              NaN   28.0
# 202099               NaN              NaN              NaN    NaN
#
# [202100 rows x 64 columns]

# %%
date_range = pd.date_range(
    # start=df['dataInicioSintomas'].min(), Notificação ou início dos sintomas?
    start=df['dataNotificacao'].min(),
    end=df['dataEncerramento'].max(),
    freq='D'
)

sir = pd.DataFrame(
    index=date_range, 
    columns=['I', 'R'], 
    dtype='int'
)

# %%
df[df["dataEncerramento"].isnull()].shape[0]
# Out:
# 72890

# %%
# df = df.dropna(axis=0, subset=['dataEncerramento'])

# %%
pd.set_option('future.no_silent_downcasting', True)
sir = sir.fillna(0)

for i, row in df.iterrows():
    
    start = row['dataNotificacao']
    end = start + pd.Timedelta(days=7)
    # end = row['dataEncerramento']
    
    if pd.isna(end):  
        sir.loc[start:, 'I'] += 1
    else: 
        assert start <= end, f"Inconsistency at row {i}, start={start}, end={end}"
        sir.loc[start:end - pd.Timedelta(days=1), 'I'] += 1
        sir.loc[end:, 'R'] += 1

# %%
sir
# Out:
#               I         R
# 2020-01-02  1.0       0.0
# 2020-01-03  1.0       0.0
# 2020-01-04  1.0       0.0
# 2020-01-05  5.0       0.0
# 2020-01-06  7.0       0.0
# ...         ...       ...
# 2025-09-05  0.0  202096.0
# 2025-09-06  0.0  202096.0
# 2025-09-07  0.0  202096.0
# 2025-09-08  0.0  202096.0
# 2025-09-09  0.0  202096.0
#
# [2078 rows x 2 columns]

# %%
sir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2078 entries, 2020-01-02 to 2025-09-09
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I       2078 non-null   float64
#  1   R       2078 non-null   float64
# dtypes: float64(2)
# memory usage: 113.2 KB

# %%
sns.lineplot(data=sir["I"])
plt.show()

# %%
sns.lineplot(data=sir["I"]["2024-01-01":"2025-01-01"])
plt.show()

# %%
smoothed_sir = sir.rolling(window=7).mean() 
sns.lineplot(data=smoothed_sir["I"]["2024-01-01":"2025-01-01"])
plt.show()

# %%
sns.lineplot(data=sir["I"]["2022-01-01":"2023-01-01"])
plt.title("2022")
plt.show()

# %%
smoothed_sir = sir.rolling(window=7).mean() 
sns.lineplot(data=smoothed_sir["I"]["2022-01-01":"2023-01-01"])
plt.title("2022")
plt.show()
