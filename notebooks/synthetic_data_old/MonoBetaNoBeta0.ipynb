# %%
import sys
sys.path.append('../..')
from utils.workflow import WorkflowModel
from utils.data import RK4DataGenerator, stack_real_values, mono_beta
import utils.plotting as plotting
from utils.eval import eval_predictions, format_latex_table
import numpy as np
# Out:
# 2026-02-03 16:41:40.323139: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-03 16:41:40.572755: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-03 16:41:42.041345: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Using backend: tensorflow
# Other supported backends: tensorflow.compat.v1, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# Set the default float type to float64
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770147703.900036  142848 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1770147703.909382  142848 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
t_0, t_f, N = 0, 50, 100
nop_data = t_f + 1
S0, I0, R0 = 99, 1, 0
noise_std = N * 0.00
test_t = np.linspace(t_0, t_f, nop_data)
rkdata = RK4DataGenerator(mono_beta, 
    t_0=t_0, 
    t_f=t_f, 
    N=N, 
    S0=S0, I0=I0, R0=R0
)
sir_real = rkdata.generate(test_t)
sir_data = rkdata.generate(test_t, noise_std)

# %%
plotting.plot_rk_curves(test_t, sir_real)

# %%
plotting.plot_rk_data(test_t, sir_data)

# %%
model = WorkflowModel(t_0, t_f, sir_data[:,1], test_t,
    N=N,
    beta_estimation_window=2,
    hidden_layer_size=50,
    n_hidden_layers=4,
    w_physics=15, 
    scaling="norm",
    activation="tanh",
    adam_iterations=300000,
    parallel_pinns=False, 
    # estimate_beta=True,
    early_stopping=True,
    beta_hard_constraints=False,
    adaptative_wdata=False,
    fine_tunning_using_lbfgs=False)
model.S0, model.I0, model.beta0
# Out:
# Compiling model...
# 'compile' took 0.006525 s
# (np.float64(0.99), np.float64(0.01), None)

# %%
model.train()
# Out:
# (<deepxde.model.LossHistory at 0x7f1776223b90>,
#  <deepxde.model.TrainState at 0x7f183a646450>)

# %%
plotting.plot_losshistory(model.losshistory)

# %%
plotting.plot_phys_losshistory(model.losshistory, model.n_physics)

# %%
plotting.plot_data_losshistory(model.losshistory)

# %%
predictions = model.predict(test_t)

# %%
plotting.plot_results(sir_real, sir_data, predictions, test_t, N=N)

# %%
real_beta = mono_beta(test_t)
plotting.plot_beta_comparison(real_beta, predictions[:,2], test_t)

# %%
if model.data_weight_hist:
    plotting.plot_wdata(model.data_weight_hist)

# %%
real_values = stack_real_values(sir_real, real_beta)
predictions = eval_predictions(real_values, predictions)

# %%
predictions
# Out:
#   compartiment      RMSE        L2  L-infinity
# 0            S  0.025505  0.000464    0.058083
# 1            I  0.015588  0.000879    0.031971
# 2         beta  0.004071  0.015032    0.012283

# %%
format_latex_table(predictions)
# Out:
# '\\begin{tabular}{llrrr}\n\\toprule\n & compartiment & RMSE & L2 & L-infinity \\\\\n\\midrule\n0 & S & 0.025505 & 0.000464 & 0.058083 \\\\\n1 & I & 0.015588 & 0.000879 & 0.031971 \\\\\n2 & beta & 0.004071 & 0.015032 & 0.012283 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
model.formated_total_training_time
# Out:
# '00:07:26'
